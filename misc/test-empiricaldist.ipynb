# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from empiricaldist import Pmf

# %%
d6 = Pmf.from_seq([1,2,3,4,5,6])
isinstance(d6, pd.Series)
# Out:
# True

# %%
d6.plot()
# Out:
# <AxesSubplot: >

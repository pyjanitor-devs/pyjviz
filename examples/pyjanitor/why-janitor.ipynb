# %%
import numpy as np
import pandas as pd
import janitor
import pyjviz

# Sample Data curated for this example                                                                                                                                                  
company_sales = {
    "SalesMonth": ["Jan", "Feb", "Mar", "April"],
    "Company1": [150.0, 200.0, 300.0, 400.0],
    "Company2": [180.0, 250.0, np.nan, 500.0],
    "Company3": [400.0, 500.0, 600.0, 675.0],
}

with pyjviz.CB("WHY JANITOR?") as sg:
    df = (
        pd.DataFrame.from_dict(company_sales)
        .remove_columns(["Company1"])
        .dropna(subset=["Company2", "Company3"])
        .rename_column("Company2", "Amazon")
        .rename_column("Company3", "Facebook")
        .add_column("Google", [450.0, 550.0, 800.0])
    )

pyjviz.show(vertical=False)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 7.1.0 (20230122.1345)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg height="117pt" viewBox="0.00 0.00 1999.00 117.00" width="1999pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 113)">
#   <title>
#    G
#   </title>
#   <polygon fill="white" points="-4,4 -4,-113 1995,-113 1995,4 -4,4" stroke="none"/>
#   <g class="cluster" id="clust1">
#    <title>
#     cluster_d2520992944675248478
#    </title>
#    <polygon fill="none" points="8,-8 8,-101 1983,-101 1983,-8 8,-8" stroke="black"/>
#    <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="middle" x="995.5" y="-85.8">
#     WHY JANITOR?
#    </text>
#   </g>
#   <!-- node_d5867910482523202395 -->
#   <g class="node" id="node1">
#    <title>
#     node_d5867910482523202395
#    </title>
#    <g cursor="pointer" id="a_node1" onclick="     window.open('', '_blank', 'width=800,height=200').document.body.innerHTML = `&lt;table border=&quot;1&quot; class=&quot;dataframe&quot;&gt;
#   &lt;thead&gt;
#     &lt;tr style=&quot;text-align: right;&quot;&gt;
#       &lt;th&gt;&lt;/th&gt;
#       &lt;th&gt;SalesMonth&lt;/th&gt;
#       &lt;th&gt;Company1&lt;/th&gt;
#       &lt;th&gt;Company2&lt;/th&gt;
#       &lt;th&gt;Company3&lt;/th&gt;
#     &lt;/tr&gt;
#   &lt;/thead&gt;
#   &lt;tbody&gt;
#     &lt;tr&gt;
#       &lt;th&gt;0&lt;/th&gt;
#       &lt;td&gt;Jan&lt;/td&gt;
#       &lt;td&gt;150.0&lt;/td&gt;
#       &lt;td&gt;180.0&lt;/td&gt;
#       &lt;td&gt;400.0&lt;/td&gt;
#     &lt;/tr&gt;
#     &lt;tr&gt;
#       &lt;th&gt;1&lt;/th&gt;
#       &lt;td&gt;Feb&lt;/td&gt;
#       &lt;td&gt;200.0&lt;/td&gt;
#       &lt;td&gt;250.0&lt;/td&gt;
#       &lt;td&gt;500.0&lt;/td&gt;
#     &lt;/tr&gt;
#     &lt;tr&gt;
#       &lt;th&gt;2&lt;/th&gt;
#       &lt;td&gt;Mar&lt;/td&gt;
#       &lt;td&gt;300.0&lt;/td&gt;
#       &lt;td&gt;nan&lt;/td&gt;
#       &lt;td&gt;600.0&lt;/td&gt;
#     &lt;/tr&gt;
#     &lt;tr&gt;
#       &lt;th&gt;3&lt;/th&gt;
#       &lt;td&gt;April&lt;/td&gt;
#       &lt;td&gt;400.0&lt;/td&gt;
#       &lt;td&gt;500.0&lt;/td&gt;
#       &lt;td&gt;675.0&lt;/td&gt;
#     &lt;/tr&gt;
#   &lt;/tbody&gt;
# &lt;/table&gt;`     ">
#     <polygon fill="#880000" fill-opacity="0.133333" points="149,-70 16,-70 16,-16 149,-16 149,-70" stroke="#880000" stroke-opacity="0.133333"/>
#     <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="28.5" y="-50.8">
#      DataFrame
#     </text>
#     <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="105.5" y="-50.8">
#      (4, 4)
#     </text>
#     <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="32" y="-28.8">
#     </text>
#     <text font-family="small" font-size="8.00" font-weight="bold" text-anchor="start" x="36" y="-28.8">
#      ObjState#0
#     </text>
#     <text font-family="small" font-size="8.00" text-anchor="start" x="88" y="-28.8">
#     </text>
#     <text font-family="small" font-size="8.00" font-style="italic" text-anchor="start" x="91" y="-28.8">
#     </text>
#    </g>
#   </g>
#   <!-- node_8314288649915503218 -->
#   <g class="node" id="node7">
#    <title>
#     node_8314288649915503218
#    </title>
#    <polygon fill="lightgrey" points="365,-61 197,-61 197,-25 365,-25 365,-61" stroke="none"/>
#    <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="209" y="-38.8">
#     remove_columns(df, ...)
#    </text>
#   </g>
#   <!-- node_d5867910482523202395&#45;&gt;node_8314288649915503218 -->
#   <g class="edge" id="edge1">
#    <title>
#     node_d5867910482523202395-&gt;node_8314288649915503218
#    </title>
#    <path d="M149.48,-43C161.17,-43 173.55,-43 185.85,-43" fill="none" stroke="black"/>
#    <polygon fill="black" points="185.58,-46.5 195.58,-43 185.58,-39.5 185.58,-46.5" stroke="black"/>
#    <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="middle" x="173" y="-46.8">
#     df
#    </text>
#   </g>
#   <!-- node_d8792800065352210021 -->
#   <g class="node" id="node2">
#    <title>
#     node_d8792800065352210021
#    </title>
#    <g cursor="pointer" id="a_node2" onclick="     window.open('', '_blank', 'width=800,height=200').document.body.innerHTML = `&lt;table border=&quot;1&quot; class=&quot;dataframe&quot;&gt;
#   &lt;thead&gt;
#     &lt;tr style=&quot;text-align: right;&quot;&gt;
#       &lt;th&gt;&lt;/th&gt;
#       &lt;th&gt;SalesMonth&lt;/th&gt;
#       &lt;th&gt;Company2&lt;/th&gt;
#       &lt;th&gt;Company3&lt;/th&gt;
#     &lt;/tr&gt;
#   &lt;/thead&gt;
#   &lt;tbody&gt;
#     &lt;tr&gt;
#       &lt;th&gt;0&lt;/th&gt;
#       &lt;td&gt;Jan&lt;/td&gt;
#       &lt;td&gt;180.0&lt;/td&gt;
#       &lt;td&gt;400.0&lt;/td&gt;
#     &lt;/tr&gt;
#     &lt;tr&gt;
#       &lt;th&gt;1&lt;/th&gt;
#       &lt;td&gt;Feb&lt;/td&gt;
#       &lt;td&gt;250.0&lt;/td&gt;
#       &lt;td&gt;500.0&lt;/td&gt;
#     &lt;/tr&gt;
#     &lt;tr&gt;
#       &lt;th&gt;2&lt;/th&gt;
#       &lt;td&gt;Mar&lt;/td&gt;
#       &lt;td&gt;nan&lt;/td&gt;
#       &lt;td&gt;600.0&lt;/td&gt;
#     &lt;/tr&gt;
#     &lt;tr&gt;
#       &lt;th&gt;3&lt;/th&gt;
#       &lt;td&gt;April&lt;/td&gt;
#       &lt;td&gt;500.0&lt;/td&gt;
#       &lt;td&gt;675.0&lt;/td&gt;
#     &lt;/tr&gt;
#   &lt;/tbody&gt;
# &lt;/table&gt;`     ">
#     <polygon fill="#880000" fill-opacity="0.133333" points="535,-70 402,-70 402,-16 535,-16 535,-70" stroke="#880000" stroke-opacity="0.133333"/>
#     <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="414.5" y="-50.8">
#      DataFrame
#     </text>
#     <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="491.5" y="-50.8">
#      (4, 3)
#     </text>
#     <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="418" y="-28.8">
#     </text>
#     <text font-family="small" font-size="8.00" font-weight="bold" text-anchor="start" x="422" y="-28.8">
#      ObjState#1
#     </text>
#     <text font-family="small" font-size="8.00" text-anchor="start" x="474" y="-28.8">
#     </text>
#     <text font-family="small" font-size="8.00" font-style="italic" text-anchor="start" x="477" y="-28.8">
#     </text>
#    </g>
#   </g>
#   <!-- node_4256113115048167896 -->
#   <g class="node" id="node8">
#    <title>
#     node_4256113115048167896
#    </title>
#    <polygon fill="lightgrey" points="689,-61 583,-61 583,-25 689,-25 689,-61" stroke="none"/>
#    <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="595" y="-38.8">
#     dropna(df, ...)
#    </text>
#   </g>
#   <!-- node_d8792800065352210021&#45;&gt;node_4256113115048167896 -->
#   <g class="edge" id="edge3">
#    <title>
#     node_d8792800065352210021-&gt;node_4256113115048167896
#    </title>
#    <path d="M535.39,-43C547.41,-43 559.93,-43 571.87,-43" fill="none" stroke="black"/>
#    <polygon fill="black" points="571.59,-46.5 581.59,-43 571.59,-39.5 571.59,-46.5" stroke="black"/>
#    <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="middle" x="559" y="-46.8">
#     df
#    </text>
#   </g>
#   <!-- node_d2673021676398466839 -->
#   <g class="node" id="node3">
#    <title>
#     node_d2673021676398466839
#    </title>
#    <g cursor="pointer" id="a_node3" onclick="     window.open('', '_blank', 'width=800,height=200').document.body.innerHTML = `&lt;table border=&quot;1&quot; class=&quot;dataframe&quot;&gt;
#   &lt;thead&gt;
#     &lt;tr style=&quot;text-align: right;&quot;&gt;
#       &lt;th&gt;&lt;/th&gt;
#       &lt;th&gt;SalesMonth&lt;/th&gt;
#       &lt;th&gt;Company2&lt;/th&gt;
#       &lt;th&gt;Company3&lt;/th&gt;
#     &lt;/tr&gt;
#   &lt;/thead&gt;
#   &lt;tbody&gt;
#     &lt;tr&gt;
#       &lt;th&gt;0&lt;/th&gt;
#       &lt;td&gt;Jan&lt;/td&gt;
#       &lt;td&gt;180.0&lt;/td&gt;
#       &lt;td&gt;400.0&lt;/td&gt;
#     &lt;/tr&gt;
#     &lt;tr&gt;
#       &lt;th&gt;1&lt;/th&gt;
#       &lt;td&gt;Feb&lt;/td&gt;
#       &lt;td&gt;250.0&lt;/td&gt;
#       &lt;td&gt;500.0&lt;/td&gt;
#     &lt;/tr&gt;
#     &lt;tr&gt;
#       &lt;th&gt;3&lt;/th&gt;
#       &lt;td&gt;April&lt;/td&gt;

# %%
with pyjviz.CB("JANITOR!!!") as sg:
    df1 = (
        pd.DataFrame(df)
        .add_column("Netflix", [50.0, 20.0, 80.0])
        .drop('SalesMonth', axis = 1)
        .make_plot()
    )

pyjviz.show(vertical=False)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 7.1.0 (20230122.1345)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg height="117pt" viewBox="0.00 0.00 838.00 117.00" width="838pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 113)">
#   <title>
#    G
#   </title>
#   <polygon fill="white" points="-4,4 -4,-113 834,-113 834,4 -4,4" stroke="none"/>
#   <g class="cluster" id="clust1">
#    <title>
#     cluster_208535996992502224
#    </title>
#    <polygon fill="none" points="8,-8 8,-101 822,-101 822,-8 8,-8" stroke="black"/>
#    <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="middle" x="415" y="-85.8">
#     JANITOR!!!
#    </text>
#   </g>
#   <!-- node_6567965521267649188 -->
#   <g class="node" id="node1">
#    <title>
#     node_6567965521267649188
#    </title>
#    <g cursor="pointer" id="a_node1" onclick="     window.open('', '_blank', 'width=800,height=200').document.body.innerHTML = `&lt;table border=&quot;1&quot; class=&quot;dataframe&quot;&gt;
#   &lt;thead&gt;
#     &lt;tr style=&quot;text-align: right;&quot;&gt;
#       &lt;th&gt;&lt;/th&gt;
#       &lt;th&gt;SalesMonth&lt;/th&gt;
#       &lt;th&gt;Amazon&lt;/th&gt;
#       &lt;th&gt;Facebook&lt;/th&gt;
#       &lt;th&gt;Google&lt;/th&gt;
#     &lt;/tr&gt;
#   &lt;/thead&gt;
#   &lt;tbody&gt;
#     &lt;tr&gt;
#       &lt;th&gt;0&lt;/th&gt;
#       &lt;td&gt;Jan&lt;/td&gt;
#       &lt;td&gt;180.0&lt;/td&gt;
#       &lt;td&gt;400.0&lt;/td&gt;
#       &lt;td&gt;450.0&lt;/td&gt;
#     &lt;/tr&gt;
#     &lt;tr&gt;
#       &lt;th&gt;1&lt;/th&gt;
#       &lt;td&gt;Feb&lt;/td&gt;
#       &lt;td&gt;250.0&lt;/td&gt;
#       &lt;td&gt;500.0&lt;/td&gt;
#       &lt;td&gt;550.0&lt;/td&gt;
#     &lt;/tr&gt;
#     &lt;tr&gt;
#       &lt;th&gt;3&lt;/th&gt;
#       &lt;td&gt;April&lt;/td&gt;
#       &lt;td&gt;500.0&lt;/td&gt;
#       &lt;td&gt;675.0&lt;/td&gt;
#       &lt;td&gt;800.0&lt;/td&gt;
#     &lt;/tr&gt;
#   &lt;/tbody&gt;
# &lt;/table&gt;`     ">
#     <polygon fill="#880000" fill-opacity="0.133333" points="149,-70 16,-70 16,-16 149,-16 149,-70" stroke="#880000" stroke-opacity="0.133333"/>
#     <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="28.5" y="-50.8">
#      DataFrame
#     </text>
#     <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="105.5" y="-50.8">
#      (3, 4)
#     </text>
#     <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="32" y="-28.8">
#     </text>
#     <text font-family="small" font-size="8.00" font-weight="bold" text-anchor="start" x="36" y="-28.8">
#      ObjState#6
#     </text>
#     <text font-family="small" font-size="8.00" text-anchor="start" x="88" y="-28.8">
#     </text>
#     <text font-family="small" font-size="8.00" font-style="italic" text-anchor="start" x="91" y="-28.8">
#     </text>
#    </g>
#   </g>
#   <!-- node_d5650818203558799891 -->
#   <g class="node" id="node4">
#    <title>
#     node_d5650818203558799891
#    </title>
#    <polygon fill="lightgrey" points="335,-61 197,-61 197,-25 335,-25 335,-61" stroke="none"/>
#    <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="209" y="-38.8">
#     add_column(df, ...)
#    </text>
#   </g>
#   <!-- node_6567965521267649188&#45;&gt;node_d5650818203558799891 -->
#   <g class="edge" id="edge1">
#    <title>
#     node_6567965521267649188-&gt;node_d5650818203558799891
#    </title>
#    <path d="M149.28,-43C161.04,-43 173.41,-43 185.51,-43" fill="none" stroke="black"/>
#    <polygon fill="black" points="185.49,-46.5 195.49,-43 185.49,-39.5 185.49,-46.5" stroke="black"/>
#    <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="middle" x="173" y="-46.8">
#     df
#    </text>
#   </g>
#   <!-- node_d8823500198166536887 -->
#   <g class="node" id="node2">
#    <title>
#     node_d8823500198166536887
#    </title>
#    <g cursor="pointer" id="a_node2" onclick="     window.open('', '_blank', 'width=800,height=200').document.body.innerHTML = `&lt;table border=&quot;1&quot; class=&quot;dataframe&quot;&gt;
#   &lt;thead&gt;
#     &lt;tr style=&quot;text-align: right;&quot;&gt;
#       &lt;th&gt;&lt;/th&gt;
#       &lt;th&gt;SalesMonth&lt;/th&gt;
#       &lt;th&gt;Amazon&lt;/th&gt;
#       &lt;th&gt;Facebook&lt;/th&gt;
#       &lt;th&gt;Google&lt;/th&gt;
#       &lt;th&gt;Netflix&lt;/th&gt;
#     &lt;/tr&gt;
#   &lt;/thead&gt;
#   &lt;tbody&gt;
#     &lt;tr&gt;
#       &lt;th&gt;0&lt;/th&gt;
#       &lt;td&gt;Jan&lt;/td&gt;
#       &lt;td&gt;180.0&lt;/td&gt;
#       &lt;td&gt;400.0&lt;/td&gt;
#       &lt;td&gt;450.0&lt;/td&gt;
#       &lt;td&gt;50.0&lt;/td&gt;
#     &lt;/tr&gt;
#     &lt;tr&gt;
#       &lt;th&gt;1&lt;/th&gt;
#       &lt;td&gt;Feb&lt;/td&gt;
#       &lt;td&gt;250.0&lt;/td&gt;
#       &lt;td&gt;500.0&lt;/td&gt;
#       &lt;td&gt;550.0&lt;/td&gt;
#       &lt;td&gt;20.0&lt;/td&gt;
#     &lt;/tr&gt;
#     &lt;tr&gt;
#       &lt;th&gt;3&lt;/th&gt;
#       &lt;td&gt;April&lt;/td&gt;
#       &lt;td&gt;500.0&lt;/td&gt;
#       &lt;td&gt;675.0&lt;/td&gt;
#       &lt;td&gt;800.0&lt;/td&gt;
#       &lt;td&gt;80.0&lt;/td&gt;
#     &lt;/tr&gt;
#   &lt;/tbody&gt;
# &lt;/table&gt;`     ">
#     <polygon fill="#880000" fill-opacity="0.133333" points="505,-70 372,-70 372,-16 505,-16 505,-70" stroke="#880000" stroke-opacity="0.133333"/>
#     <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="384.5" y="-50.8">
#      DataFrame
#     </text>
#     <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="461.5" y="-50.8">
#      (3, 5)
#     </text>
#     <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="388" y="-28.8">
#     </text>
#     <text font-family="small" font-size="8.00" font-weight="bold" text-anchor="start" x="392" y="-28.8">
#      ObjState#7
#     </text>
#     <text font-family="small" font-size="8.00" text-anchor="start" x="444" y="-28.8">
#     </text>
#     <text font-family="small" font-size="8.00" font-style="italic" text-anchor="start" x="447" y="-28.8">
#     </text>
#    </g>
#   </g>
#   <!-- node_3956080635669473147 -->
#   <g class="node" id="node5">
#    <title>
#     node_3956080635669473147
#    </title>
#    <polygon fill="lightgrey" points="644,-61 553,-61 553,-25 644,-25 644,-61" stroke="none"/>
#    <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="565.5" y="-38.8">
#     drop(df, ...)
#    </text>
#   </g>
#   <!-- node_d8823500198166536887&#45;&gt;node_3956080635669473147 -->
#   <g class="edge" id="edge3">
#    <title>
#     node_d8823500198166536887-&gt;node_3956080635669473147
#    </title>
#    <path d="M505.13,-43C517.47,-43 530.25,-43 542.24,-43" fill="none" stroke="black"/>
#    <polygon fill="black" points="541.92,-46.5 551.92,-43 541.92,-39.5 541.92,-46.5" stroke="black"/>
#    <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="middle" x="529" y="-46.8">
#     df
#    </text>
#   </g>
#   <!-- node_d740806377434052435 -->
#   <g class="node" id="node3">
#    <title>
#     node_d740806377434052435
#    </title>
#    <g cursor="pointer" id="a_node3" onclick="     window.open('', '_blank', 'width=900,height=500').document.body.innerHTML = `&lt;img src='data:image/png;base64,...'&gt;&lt;/img&gt;`     ">
#     <polygon fill="#440560" fill-opacity="0.133333" points="814,-70 681,-70 681,-16 814,-16 814,-70" stroke="#440560" stroke-opacity="0.133333"/>
#     <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="693.5" y="-50.8">
#      DataFrame
#     </text>
#     <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="770.5" y="-50.8">
#      (3, 4)
#     </text>
#     <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="697" y="-28.8">
#     </text>
#     <text font-family="small" font-size="8.00" font-weight="bold" text-anchor="start" x="701" y="-28.8">
#      ObjState#8
#     </text>
#     <text font-family="small" font-size="8.00" text-anchor="start" x="753" y="

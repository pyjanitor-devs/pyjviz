# %%
import numpy as np
import pandas as pd
import janitor
import pyjviz

# Sample Data curated for this example                                                                                                                                                  
company_sales = {
    "SalesMonth": ["Jan", "Feb", "Mar", "April"],
    "Company1": [150.0, 200.0, 300.0, 400.0],
    "Company2": [180.0, 250.0, np.nan, 500.0],
    "Company3": [400.0, 500.0, 600.0, 675.0],
}

print(pd.DataFrame.from_dict(company_sales))

with pyjviz.CB("WHY JANITOR?") as sg:
    df = (
        pd.DataFrame.from_dict(company_sales)
        .remove_columns(["Company1"])
        .dropna(subset=["Company2", "Company3"])
        .rename_column("Company2", "Amazon")
        .rename_column("Company3", "Facebook")
        .add_column("Google", [450.0, 550.0, 800.0])
    )
    #print(df)

pyjviz.show(vertical=False)
# Out:
# setting up triple_store: <pyjviz.fstriplestore.FSTripleOutputOneShot object at 0x7f5426d66320>
#   SalesMonth  Company1  Company2  Company3
# 0        Jan     150.0     180.0     400.0
# 1        Feb     200.0     250.0     500.0
# 2        Mar     300.0       NaN     600.0
# 3      April     400.0     500.0     675.0
# remove_columns df POSITIONAL_OR_KEYWORD
# remove_columns column_names POSITIONAL_OR_KEYWORD
# arg id: 140000362592480 False
# ObjState ctor 140000362592480 <pyjviz.obj_utils.ObjId object at 0x7f5424642770>
# ObjState ctor 139999364524224 <pyjviz.obj_utils.ObjId object at 0x7f5424642920>
# dropna df POSITIONAL_OR_KEYWORD
# dropna kwargs VAR_KEYWORD
# arg id: 139999364524224 True
# call dropna
# ObjState ctor 139999364528064 <pyjviz.obj_utils.ObjId object at 0x7f5424643c40>
# rename_column df POSITIONAL_OR_KEYWORD
# rename_column old_column_name POSITIONAL_OR_KEYWORD
# rename_column new_column_name POSITIONAL_OR_KEYWORD
# arg id: 139999364528064 True
# my rename 139999364528064
# new copy: () {'deep': None}
# ObjState ctor 139999364528592 <pyjviz.obj_utils.ObjId object at 0x7f5424643d60>
# rename_column df POSITIONAL_OR_KEYWORD
# rename_column old_column_name POSITIONAL_OR_KEYWORD
# rename_column new_column_name POSITIONAL_OR_KEYWORD
# arg id: 139999364528592 True
# my rename 139999364528592
# new copy: () {'deep': None}
# ObjState ctor 139999362613552 <pyjviz.obj_utils.ObjId object at 0x7f5424643850>
# add_column df POSITIONAL_OR_KEYWORD
# add_column column_name POSITIONAL_OR_KEYWORD
# add_column value POSITIONAL_OR_KEYWORD
# arg id: 139999362613552 True
# new copy: () {}
# ObjState ctor 139999362614560 <pyjviz.obj_utils.ObjId object at 0x7f5424470610>
# obj_state: https://github.com/pyjanitor-devs/pyjviz/ObjState#0
# obj_state: https://github.com/pyjanitor-devs/pyjviz/ObjState#1
# obj_state: https://github.com/pyjanitor-devs/pyjviz/ObjState#2
# obj_state: https://github.com/pyjanitor-devs/pyjviz/ObjState#3
# obj_state: https://github.com/pyjanitor-devs/pyjviz/ObjState#4
# obj_state: https://github.com/pyjanitor-devs/pyjviz/ObjState#5
# /home/asmirnov/projects/pandas_flavor/pandas_flavor/register.py:159: UserWarning: registration of accessor <class 'pandas_flavor.register.register_dataframe_method.<locals>.inner.<locals>.AccessorMethod'> under name 'describe' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexisting attribute with the same name.
#   register_dataframe_accessor(method.__name__)(AccessorMethod)
# /home/asmirnov/projects/pandas_flavor/pandas_flavor/register.py:159: UserWarning: registration of accessor <class 'pandas_flavor.register.register_dataframe_method.<locals>.inner.<locals>.AccessorMethod'> under name 'drop' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexisting attribute with the same name.
#   register_dataframe_accessor(method.__name__)(AccessorMethod)
# /home/asmirnov/projects/pandas_flavor/pandas_flavor/register.py:159: UserWarning: registration of accessor <class 'pandas_flavor.register.register_dataframe_method.<locals>.inner.<locals>.AccessorMethod'> under name 'copy' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexisting attribute with the same name.
#   register_dataframe_accessor(method.__name__)(AccessorMethod)
# replace 6c2b1185-6347-4350-af0b-e322c0f8dc50
# replace 418b9cec-579c-46b8-9c70-211727028489
# replace f29a53d1-85b6-4052-a7f2-9319a91f1418
# replace 6bdcd039-a633-4a96-9820-da5675f64a17
# replace 77ece9d5-b9d5-4f8c-a2fa-36bfb85e3cdd
# replace 0d86f1cb-c652-4f21-b354-008c8c8d9396
# replace 6c2b1185-6347-4350-af0b-e322c0f8dc50
# replace 418b9cec-579c-46b8-9c70-211727028489
# replace f29a53d1-85b6-4052-a7f2-9319a91f1418
# replace 6bdcd039-a633-4a96-9820-da5675f64a17
# replace 77ece9d5-b9d5-4f8c-a2fa-36bfb85e3cdd
# replace 0d86f1cb-c652-4f21-b354-008c8c8d9396
# replace 6c2b1185-6347-4350-af0b-e322c0f8dc50
# replace 418b9cec-579c-46b8-9c70-211727028489
# replace f29a53d1-85b6-4052-a7f2-9319a91f1418
# replace 6bdcd039-a633-4a96-9820-da5675f64a17
# replace 77ece9d5-b9d5-4f8c-a2fa-36bfb85e3cdd
# replace 0d86f1cb-c652-4f21-b354-008c8c8d9396
# replace 6c2b1185-6347-4350-af0b-e322c0f8dc50
# replace 418b9cec-579c-46b8-9c70-211727028489
# replace f29a53d1-85b6-4052-a7f2-9319a91f1418
# replace 6bdcd039-a633-4a96-9820-da5675f64a17
# replace 77ece9d5-b9d5-4f8c-a2fa-36bfb85e3cdd
# replace 0d86f1cb-c652-4f21-b354-008c8c8d9396
# replace 6c2b1185-6347-4350-af0b-e322c0f8dc50
# replace 418b9cec-579c-46b8-9c70-211727028489
# replace f29a53d1-85b6-4052-a7f2-9319a91f1418
# replace 6bdcd039-a633-4a96-9820-da5675f64a17
# replace 77ece9d5-b9d5-4f8c-a2fa-36bfb85e3cdd
# replace 0d86f1cb-c652-4f21-b354-008c8c8d9396
# replace 6c2b1185-6347-4350-af0b-e322c0f8dc50
# replace 418b9cec-579c-46b8-9c70-211727028489
# replace f29a53d1-85b6-4052-a7f2-9319a91f1418
# replace 6bdcd039-a633-4a96-9820-da5675f64a17
# replace 77ece9d5-b9d5-4f8c-a2fa-36bfb85e3cdd
# replace 0d86f1cb-c652-4f21-b354-008c8c8d9396
# <?xml version="1.0" encoding="utf-8"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg height="117pt" viewBox="0.00 0.00 3506.00 117.00" width="3506pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 113)">
#   <title>
#    G
#   </title>
#   <polygon fill="white" points="-4,4 -4,-113 3502,-113 3502,4 -4,4" stroke="transparent"/>
#   <g class="cluster" id="clust1">
#    <title>
#     cluster_d6417878892024477336
#    </title>
#    <polygon fill="none" points="8,-8 8,-101 3490,-101 3490,-8 8,-8" stroke="black"/>
#    <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="middle" x="1749" y="-85.8">
#     WHY JANITOR?
#    </text>
#   </g>
#   <!-- node_d5140106525959342685 -->
#   <g class="node" id="node1">
#    <title>
#     node_d5140106525959342685
#    </title>
#    <g cursor="pointer" id="a_node1" onclick="         window.open('', '_blank', 'width=800,height=200').document.body.innerHTML = `&lt;table border=&quot;1&quot; class=&quot;dataframe&quot;&gt;
#   &lt;thead&gt;
#     &lt;tr style=&quot;text-align: right;&quot;&gt;
#       &lt;th&gt;&lt;/th&gt;
#       &lt;th&gt;SalesMonth&lt;/th&gt;
#       &lt;th&gt;Company1&lt;/th&gt;
#       &lt;th&gt;Company2&lt;/th&gt;
#       &lt;th&gt;Company3&lt;/th&gt;
#     &lt;/tr&gt;
#   &lt;/thead&gt;
#   &lt;tbody&gt;
#     &lt;tr&gt;
#       &lt;th&gt;0&lt;/th&gt;
#       &lt;td&gt;Jan&lt;/td&gt;
#       &lt;td&gt;150.0&lt;/td&gt;
#       &lt;td&gt;180.0&lt;/td&gt;
#       &lt;td&gt;400.0&lt;/td&gt;
#     &lt;/tr&gt;
#     &lt;tr&gt;
#       &lt;th&gt;1&lt;/th&gt;
#       &lt;td&gt;Feb&lt;/td&gt;
#       &lt;td&gt;200.0&lt;/td&gt;
#       &lt;td&gt;250.0&lt;/td&gt;
#       &lt;td&gt;500.0&lt;/td&gt;
#     &lt;/tr&gt;
#     &lt;tr&gt;
#       &lt;th&gt;2&lt;/th&gt;
#       &lt;td&gt;Mar&lt;/td&gt;
#       &lt;td&gt;300.0&lt;/td&gt;
#       &lt;td&gt;nan&lt;/td&gt;
#       &lt;td&gt;600.0&lt;/td&gt;
#     &lt;/tr&gt;
#     &lt;tr&gt;
#       &lt;th&gt;3&lt;/th&gt;
#       &lt;td&gt;April&lt;/td&gt;
#       &lt;td&gt;400.0&lt;/td&gt;
#       &lt;td&gt;500.0&lt;/td&gt;
#       &lt;td&gt;675.0&lt;/td&gt;
#     &lt;/tr&gt;
#   &lt;/tbody&gt;
# &lt;/table&gt;`         ">
#     <polygon fill="#880000" fill-opacity="0.133333" points="149,-70 16,-70 16,-16 149,-16 149,-70" stroke="#880000" stroke-opacity="0.133333"/>
#     <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="28.5" y="-50.8">
#      DataFrame
#     </text>
#     <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="105.5" y="-50.8">
#      (4, 4)
#     </text>
#     <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="32" y="-28.8">
#     </text>
#     <text font-family="small" font-size="8.00" font-weight="bold" text-anchor="start" x="36" y="-28.8">
#      ObjState#0
#     </text>
#     <text font-family="small" font-size="8.00" text-anchor="start" x="88" y="-28.8">
#     </text>
#     <text font-family="small" font-size="8.00" font-style="italic" text-anchor="start" x="91" y="-28.8">
#     </text>
#    </g>
#   </g>
#   <!-- node_4720471796522148371 -->
#   <g class="node" id="node7">
#    <title>
#     node_4720471796522148371
#    </title>
#    <polygon fill="lightgrey" points="553,-61 197,-61 197,-25 553,-25 553,-61" stroke="transparent"/>
#    <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" font-style="italic" text-anchor="start" x="209" y="-39.8">
#     remove_columns
#    </text>
#    <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="314" y="-39.8">
#     (
#    </text>
#    <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" font-weight="bold" text-anchor="start" x="327" y="-39.8">
#     df
#    </text>
#    <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="340" y="-39.8">
#     , column_names = ['Company1'])
#    </text>
#   </g>
#   <!-- node_d5140106525959342685&#45;&gt;node_4720471796522148371 -->
#   <g class="edge" id="edge1">
#    <title>
#     node_d5140106525959342685-&gt;node_4720471796522148371
#    </title>
#    <path d="M149.06,-43C160.72,-43 173.39,-43 186.56,-43" fill="none" stroke="black"/>
#    <polygon fill="black" points="186.72,-46.5 196.72,-43 186.72,-39.5 186.72,-46.5" stroke="black"/>
#    <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="middle" x="173" y="-46.8">
#     df
#    </text>
#   </g>
#   <!-- node_d7279270352271317227 -->
#   <g class="node" id="node2">
#    <title>
#     node_d7279270352271317227
#    </title>
#    <g cursor="pointer" id="a_node2" onclick="         window.open('', '_blank', 'width=800,height=200').document.body.innerHTML = `&lt;table border=&quot;1&quot; class=&quot;dataframe&quot;&gt;
#   &lt;thead&gt;
#     &lt;tr style=&quot;text-align: right;&quot;&gt;
#       &lt;th&gt;&lt;/th&gt;
#       &lt;th&gt;SalesMonth&lt;/th&gt;
#       &lt;th&gt;Company2&lt;/th&gt;
#       &lt;th&gt;Company3&lt;/th&gt;
#     &lt;/tr&gt;
#   &lt;/thead&gt;
#   &lt;tbody&gt;
#     &lt;tr&gt;
#       &lt;th&gt;0&lt;/th&gt;
#       &lt;td&gt;Jan&lt;/td&gt;
#       &lt;td&gt;180.0&lt;/td&gt;
#       &lt;td&gt;400.0&lt;/td&gt;
#     &lt;/tr&gt;
#     &lt;tr&gt;
#       &lt;th&gt;1&lt;/th&gt;
#       &lt;td&gt;Feb&lt;/td&gt;
#       &lt;td&gt;250.0&lt;/td&gt;
#       &lt;td&gt;500.0&lt;/td&gt;
#     &lt;/tr&gt;
#     &lt;tr&gt;
#       &lt;th&gt;2&lt;/th&gt;
#       &lt;td&gt;Mar&lt;/td&gt;
#       &lt;td&gt;nan&lt;/td&gt;
#       &lt;td&gt;600.0&lt;/td&gt;
#     &lt;/tr&gt;
#     &lt;tr&gt;
#       &lt;th&gt;3&lt;/th&gt;
#       &lt;td&gt;April&lt;/td&gt;
#       &lt;td&gt;500.0&lt;/td&gt;
#       &lt;td&gt;675.0&lt;/td&gt;
#     &lt;/tr&gt;
#   &lt;/tbody&gt;
# &lt;/table&gt;`         ">
#     <polygon fill="#880000" fill-opacity="0.133333" points="723,-70 590,-70 590,-16 723,-16 723,-70" stroke="#880000" stroke-opacity="0.133333"/>
#     <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="602.5" y="-50.8">
#      DataFrame
#     </text>
#     <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="679.5" y="-50.8">
#      (4, 3)
#     </text>
#     <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="606" y="-28.8">
#     </text>
#     <text font-family="small" font-size="8.00" font-weight="bold" text-anchor="start" x="610" y="-28.8">
#      ObjState#1
#     </text>
#     <text font-family="small" font-size="8.00" text-anchor="start" x="662" y="-28.8">
#     </text>
#     <text font-family="small" font-size="8.00" font-style="italic" text-anchor="start" x="665" y="-28.8">
#     </text>
#    </g>
#   </g>
#   <!-- node_d4262833318573353149 -->
#   <g class="node" id="node8">
#    <title>
#     node_d4262833318573353149
#    </title>
#    <polygon fill="lightgrey" points="1091,-61 771,-61 771,-25 1091,-25 1091,-61" stroke="transparent"/>
#    <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" font-style="italic" text-anchor="start" x="783" y="-39.8">
#     dropna
#    </text>
#    <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="826" y="-39.8">
#     (
#    </text>
#    <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" font-weight="bold" text-anchor="start" x="839" y="-39.8">
#     df
#    </text>
#    <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="start" x="852" y="-39.8">
#     , subset = ['Company2', 'Company3'])
#    </text>
#   </g>
#   <!-- node_d7279270352271317227&#45;&gt;node_d4262833318573353149 -->
#   <g class="edge" id="edge3">
#    <title>
#     node_d7279270352271317227-&gt;node_d4262833318573353149
#    </title>
#    <path d="M723.12,-43C734.85,-43 747.55,-43 760.69,-43" fill="none" stroke="black"/>
#    <polygon fill="black" points="760.81,-46.5 770.81,-43 760.81,-39.5 760.81,-46.5" stroke="black"/>
#    <text font-family="Helvetica,Arial,sans-serif" font-size="14.00" text-anchor="middle" x="747" y="-46.8">
#     df
#    </text>
#   </g>
#   <!-- node_4962541199662597702 -->
#   <g class="node"
